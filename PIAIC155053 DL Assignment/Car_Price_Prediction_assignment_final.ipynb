# %% [markdown]
# # Car Price Prediction::

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/hellbuoy/car-price-prediction

# %% [markdown]
# # Problem Statement::

# %%
# mount google drive in to your Colab enviornment
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %% [markdown]
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
# Which variables are significant in predicting the price of a car
# How well those variables describe the price of a car
# Based on various market surveys, the consulting firm has gathered a large data set of different types of cars across the America market.
#
# # task::
# We are required to model the price of cars with the available independent variables. It will be used by the management to understand how exactly the prices vary with the independent variables. They can accordingly manipulate the design of the cars, the business strategy etc. to meet certain price levels. Further, the model will be a good way for management to understand the pricing dynamics of a new market.

# %% [markdown]
# # WORKFLOW ::

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 4.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 5.Compilation Step (Note : Its a Regression problem , select loss , metrics according to it)
# 6.Train the Model with Epochs (100) and validate it
#
# 7.If the model gets overfit tune your model by changing the units , No. of layers , activation function , epochs , add dropout layer or add Regularizer according to the need .
#
# 8.Evaluation Step
#
# 9.Prediction

# %%
import pandas as pd
import numpy as np
car_data = pd.read_csv('/content/drive/MyDrive/CarPrice_Assignment.csv')

# %%
import tensorflow as tf

# %%
car_data.head()
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.0
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3       4          2               audi 100 ls  ...      24         30  13950.0
# 4       5          2                audi 100ls  ...      18         22  17450.0
#
# [5 rows x 26 columns]

# %%
car_data['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
#        'mazda glc deluxe', 'mazda 626', 'mazda glc', 'mazda rx-7 gs',
#        'mazda glc 4', 'mazda glc custom l', 'mazda glc custom',
#        'buick electra 225 custom', 'buick century luxus (sw)',
#        'buick century', 'buick skyhawk', 'buick opel isuzu deluxe',
#        'buick skylark', 'buick century special',
#        'buick regal sport coupe (turbo)', 'mercury cougar',
#        'mitsubishi mirage', 'mitsubishi lancer', 'mitsubishi outlander',
#        'mitsubishi g4', 'mitsubishi mirage g4', 'mitsubishi montero',
#        'mitsubishi pajero', 'Nissan versa', 'nissan gt-r', 'nissan rogue',
#        'nissan latio', 'nissan titan', 'nissan leaf', 'nissan juke',
#        'nissan note', 'nissan clipper', 'nissan nv200', 'nissan dayz',
#        'nissan fuga', 'nissan otti', 'nissan teana', 'nissan kicks',
#        'peugeot 504', 'peugeot 304', 'peugeot 504 (sw)', 'peugeot 604sl',
#        'peugeot 505s turbo diesel', 'plymouth fury iii',
#        'plymouth cricket', 'plymouth satellite custom (sw)',
#        'plymouth fury gran sedan', 'plymouth valiant', 'plymouth duster',
#        'porsche macan', 'porcshce panamera', 'porsche cayenne',
#        'porsche boxter', 'renault 12tl', 'renault 5 gtl', 'saab 99e',
#        'saab 99le', 'saab 99gle', 'subaru', 'subaru dl', 'subaru brz',
#        'subaru baja', 'subaru r1', 'subaru r2', 'subaru trezia',
#        'subaru tribeca', 'toyota corona mark ii', 'toyota corona',
#        'toyota corolla 1200', 'toyota corona hardtop',
#        'toyota corolla 1600 (sw)', 'toyota carina', 'toyota mark ii',
#        'toyota corolla', 'toyota corolla liftback',
#        'toyota celica gt liftback', 'toyota corolla tercel',
#        'toyota corona liftback', 'toyota starlet', 'toyota tercel',
#        'toyota cressida', 'toyota celica gt', 'toyouta tercel',
#        'vokswagen rabbit', 'volkswagen 1131 deluxe sedan',
#        'volkswagen model 111', 'volkswagen type 3', 'volkswagen 411 (sw)',
#        'volkswagen super beetle', 'volkswagen dasher', 'vw dasher',
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'], dtype=object)

# %%
#check if there are empty cells, if there are then row and column indexes will be returned where values are empty or missing
np.where(car_data.applymap(lambda x: x ==''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
car_data.isnull().any()
# Out:
# car_ID              False
# symboling           False
# CarName             False
# fueltype            False
# aspiration          False
# doornumber          False
# carbody             False
# drivewheel          False
# enginelocation      False
# wheelbase           False
# carlength           False
# carwidth            False
# carheight           False
# curbweight          False
# enginetype          False
# cylindernumber      False
# enginesize          False
# fuelsystem          False
# boreratio           False
# stroke              False
# compressionratio    False
# horsepower          False
# peakrpm             False
# citympg             False
# highwaympg          False
# price               False
# dtype: bool

# %%
# correct the name error in audi 100 ls
car_data.iloc[3,2] = 'audi 100ls'

# %%
car_data.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
car_data.drop(columns=['car_ID'], inplace = True)

# %%
# get columns so that we can use the column names for onehot encoding of catagorical featrues in next cell
car_data.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
# onehot encode all catagorical columns
final_car = pd.get_dummies(car_data, columns=['CarName','symboling','fueltype',	'aspiration',	'doornumber',	'carbody',	'drivewheel',	'enginelocation',	'enginetype',	'cylindernumber',	'fuelsystem'], drop_first = True)

# %%
final_car.head()
# Out:
#    wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0       88.6      168.8  ...                0                0
# 1       88.6      168.8  ...                0                0
# 2       94.5      171.2  ...                0                0
# 3       99.8      176.6  ...                0                0
# 4       99.4      176.6  ...                0                0
#
# [5 rows x 193 columns]

# %%
#check statistical data to see abnormal values and outliers
final_car.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  205.000000  205.000000  ...       205.000000       205.000000
# mean    98.756585  174.049268  ...         0.043902         0.004878
# std      6.021776   12.337289  ...         0.205380         0.069843
# min     86.600000  141.100000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     97.000000  173.200000  ...         0.000000         0.000000
# 75%    102.400000  183.100000  ...         0.000000         0.000000
# max    120.900000  208.100000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
#initialize a seed value so that each time we can get the same random number sequence, it will help us  as a team
# working on a common project to work on the same random data. Each new seed will generate a particular sequnce
#of random number. You can choose any seed value here of your choice
# 0.72 means we have taken 72% values for training set as we will make 72/4 = 18 rows of k fold validation data, where
# value of k will be 4 when we compile and fit our model for validation
np.random.seed(11111)
msk = np.random.rand(len(final_car)) < 0.72
train_total = final_car[msk]
test_total = final_car[~msk]

# %%
#check the length of our test and train datasets
print(len(train_total))
print(len(test_total))
# Out:
# 141
# 64

# %%
train_total.head(10)
# Out:
#     wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1        88.6      168.8  ...                0                0
# 2        94.5      171.2  ...                0                0
# 3        99.8      176.6  ...                0                0
# 4        99.4      176.6  ...                0                0
# 5        99.8      177.3  ...                0                0
# 6       105.8      192.7  ...                0                0
# 7       105.8      192.7  ...                0                0
# 8       105.8      192.7  ...                0                0
# 9        99.5      178.2  ...                0                0
# 11      101.2      176.8  ...                0                0
#
# [10 rows x 193 columns]

# %%
# check statistical overview if there are some outliers and abnormal values
train_total.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  141.000000  141.000000  ...       141.000000       141.000000
# mean    98.692199  173.658156  ...         0.035461         0.007092
# std      6.005665   12.320089  ...         0.185601         0.084215
# min     86.600000  144.600000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     96.500000  172.400000  ...         0.000000         0.000000
# 75%    102.400000  180.300000  ...         0.000000         0.000000
# max    115.600000  202.600000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
print(train_total.dtypes)
# Out:
# wheelbase          float64
# carlength          float64
# carwidth           float64
# carheight          float64
# curbweight           int64
#                     ...
# fuelsystem_idi       uint8
# fuelsystem_mfi       uint8
# fuelsystem_mpfi      uint8
# fuelsystem_spdi      uint8
# fuelsystem_spfi      uint8
# Length: 193, dtype: object

# %%
# get our price labels and store in another dataframe
train_label = train_total.loc[:,'price']
test_label = test_total.loc[:,'price']

# %%
train_label
# Out:
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
# 5      15250.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 141, dtype: float64

# %%
# drop price from oroginal training and test dataset , as price is not needed there
test_data= test_total.drop(columns = ['price'])
train_data= train_total.drop(columns = ['price'])

# %%
train_data.shape
# Out:
# (141, 192)

# %%
train_data
# Out:
#      wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1         88.6      168.8  ...                0                0
# 2         94.5      171.2  ...                0                0
# 3         99.8      176.6  ...                0                0
# 4         99.4      176.6  ...                0                0
# 5         99.8      177.3  ...                0                0
# ..         ...        ...  ...              ...              ...
# 200      109.1      188.8  ...                0                0
# 201      109.1      188.8  ...                0                0
# 202      109.1      188.8  ...                0                0
# 203      109.1      188.8  ...                0                0
# 204      109.1      188.8  ...                0                0
#
# [141 rows x 192 columns]

# %%
#get indices of the columns so that we can know how many columns we have to normalize, as catagorical columns which we
# have added with onehot encoding, do not need to be normalized.. normalizing will be done in next cell
{train_data.columns.get_loc(c): c for idx, c in enumerate(train_data.columns)}
# Out:
# {0: 'wheelbase',
#  1: 'carlength',
#  2: 'carwidth',
#  3: 'carheight',
#  4: 'curbweight',
#  5: 'enginesize',
#  6: 'boreratio',
#  7: 'stroke',
#  8: 'compressionratio',
#  9: 'horsepower',
#  10: 'peakrpm',
#  11: 'citympg',
#  12: 'highwaympg',
#  13: 'CarName_alfa-romero Quadrifoglio',
#  14: 'CarName_alfa-romero giulia',
#  15: 'CarName_alfa-romero stelvio',
#  16: 'CarName_audi 100ls',
#  17: 'CarName_audi 4000',
#  18: 'CarName_audi 5000',
#  19: 'CarName_audi 5000s (diesel)',
#  20: 'CarName_audi fox',
#  21: 'CarName_bmw 320i',
#  22: 'CarName_bmw x1',
#  23: 'CarName_bmw x3',
#  24: 'CarName_bmw x4',
#  25: 'CarName_bmw x5',
#  26: 'CarName_bmw z4',
#  27: 'CarName_buick century',
#  28: 'CarName_buick century luxus (sw)',
#  29: 'CarName_buick century special',
#  30: 'CarName_buick electra 225 custom',
#  31: 'CarName_buick opel isuzu deluxe',
#  32: 'CarName_buick regal sport coupe (turbo)',
#  33: 'CarName_buick skyhawk',
#  34: 'CarName_buick skylark',
#  35: 'CarName_chevrolet impala',
#  36: 'CarName_chevrolet monte carlo',
#  37: 'CarName_chevrolet vega 2300',
#  38: 'CarName_dodge challenger se',
#  39: 'CarName_dodge colt (sw)',
#  40: 'CarName_dodge colt hardtop',
#  41: 'CarName_dodge coronet custom',
#  42: 'CarName_dodge coronet custom (sw)',
#  43: 'CarName_dodge d200',
#  44: 'CarName_dodge dart custom',
#  45: 'CarName_dodge monaco (sw)',
#  46: 'CarName_dodge rampage',
#  47: 'CarName_honda accord',
#  48: 'CarName_honda accord cvcc',
#  49: 'CarName_honda accord lx',
#  50: 'CarName_honda civic',
#  51: 'CarName_honda civic (auto)',
#  52: 'CarName_honda civic 1300',
#  53: 'CarName_honda civic 1500 gl',
#  54: 'CarName_honda civic cvcc',
#  55: 'CarName_honda prelude',
#  56: 'CarName_isuzu D-Max ',
#  57: 'CarName_isuzu D-Max V-Cross',
#  58: 'CarName_isuzu MU-X',
#  59: 'CarName_jaguar xf',
#  60: 'CarName_jaguar xj',
#  61: 'CarName_jaguar xk',
#  62: 'CarName_maxda glc deluxe',
#  63: 'CarName_maxda rx3',
#  64: 'CarName_mazda 626',
#  65: 'CarName_mazda glc',
#  66: 'CarName_mazda glc 4',
#  67: 'CarName_mazda glc custom',
#  68: 'CarName_mazda glc custom l',
#  69: 'CarName_mazda glc deluxe',
#  70: 'CarName_mazda rx-4',
#  71: 'CarName_mazda rx-7 gs',
#  72: 'CarName_mazda rx2 coupe',
#  73: 'CarName_mercury cougar',
#  74: 'CarName_mitsubishi g4',
#  75: 'CarName_mitsubishi lancer',
#  76: 'CarName_mitsubishi mirage',
#  77: 'CarName_mitsubishi mirage g4',
#  78: 'CarName_mitsubishi montero',
#  79: 'CarName_mitsubishi outlander',
#  80: 'CarName_mitsubishi pajero',
#  81: 'CarName_nissan clipper',
#  82: 'CarName_nissan dayz',
#  83: 'CarName_nissan fuga',
#  84: 'CarName_nissan gt-r',
#  85: 'CarName_nissan juke',
#  86: 'CarName_nissan kicks',
#  87: 'CarName_nissan latio',
#  88: 'CarName_nissan leaf',
#  89: 'CarName_nissan note',
#  90: 'CarName_nissan nv200',
#  91: 'CarName_nissan otti',
#  92: 'CarName_nissan rogue',
#  93: 'CarName_nissan teana',
#  94: 'CarName_nissan titan',
#  95: 'CarName_peugeot 304',
#  96: 'CarName_peugeot 504',
#  97: 'CarName_peugeot 504 (sw)',
#  98: 'CarName_peugeot 505s turbo diesel',
#  99: 'CarName_peugeot 604sl',
#  100: 'CarName_plymouth cricket',
#  101: 'CarName_plymouth duster',
#  102: 'CarName_plymouth fury gran sedan',
#  103: 'CarName_plymouth fury iii',
#  104: 'CarName_plymouth satellite custom (sw)',
#  105: 'CarName_plymouth valiant',
#  106: 'CarName_porcshce panamera',
#  107: 'CarName_porsche boxter',
#  108: 'CarName_porsche cayenne',
#  109: 'CarName_porsche macan',
#  110: 'CarName_renault 12tl',
#  111: 'CarName_renault 5 gtl',
#  112: 'CarName_saab 99e',
#  113: 'CarName_saab 99gle',
#  114: 'CarName_saab 99le',
#  115: 'CarName_subaru',
#  116: 'CarName_subaru baja',
#  117: 'CarName_subaru brz',
#  118: 'CarName_subaru dl',
#  119: 'CarName_subaru r1',
#  120: 'CarName_subaru r2',
#  121: 'CarName_subaru trezia',
#  122: 'CarName_subaru tribeca',
#  123: 'CarName_toyota carina',
#  124: 'CarName_toyota celica gt',
#  125: 'CarName_toyota celica gt liftback',
#  126: 'CarName_toyota corolla',
#  127: 'CarName_toyota corolla 1200',
#  128: 'CarName_toyota corolla 1600 (sw)',
#  129: 'CarName_toyota corolla liftback',
#  130: 'CarName_toyota corolla tercel',
#  131: 'CarName_toyota corona',
#  132: 'CarName_toyota corona hardtop',
#  133: 'CarName_toyota corona liftback',
#  134: 'CarName_toyota corona mark ii',
#  135: 'CarName_toyota cressida',
#  136: 'CarName_toyota mark ii',
#  137: 'CarName_toyota starlet',
#  138: 'CarName_toyota tercel',
#  139: 'CarName_toyouta tercel',
#  140: 'CarName_vokswagen rabbit',
#  141: 'CarName_volkswagen 1131 deluxe sedan',
#  142: 'CarName_volkswagen 411 (sw)',
#  143: 'CarName_volkswagen dasher',
#  144: 'CarName_volkswagen model 111',
#  145: 'CarName_volkswagen rabbit',
#  146: 'CarName_volkswagen rabbit custom',
#  147: 'CarName_volkswagen super beetle',
#  148: 'CarName_volkswagen type 3',
#  149: 'CarName_volvo 144ea',
#  150: 'CarName_volvo 145e (sw)',
#  151: 'CarName_volvo 244dl',
#  152: 'CarName_volvo 245',
#  153: 'CarName_volvo 246',
#  154: 'CarName_volvo 264gl',
#  155: 'CarName_volvo diesel',
#  156: 'CarName_vw dasher',
#  157: 'CarName_vw rabbit',
#  158: 'symboling_-1',
#  159: 'symboling_0',
#  160: 'symboling_1',
#  161: 'symboling_2',
#  162: 'symboling_3',
#  163: 'fueltype_gas',
#  164: 'aspiration_turbo',
#  165: 'doornumber_two',
#  166: 'carbody_hardtop',
#  167: 'carbody_hatchback',
#  168: 'carbody_sedan',
#  169: 'carbody_wagon',
#  170: 'drivewheel_fwd',
#  171: 'drivewheel_rwd',
#  172: 'enginelocation_rear',
#  173: 'enginetype_dohcv',
#  174: 'enginetype_l',
#  175: 'enginetype_ohc',
#  176: 'enginetype_ohcf',
#  177: 'enginetype_ohcv',
#  178: 'enginetype_rotor',
#  179: 'cylindernumber_five',
#  180: 'cylindernumber_four',
#  181: 'cylindernumber_six',
#  182: 'cylindernumber_three',
#  183: 'cylindernumber_twelve',
#  184: 'cylindernumber_two',
#  185: 'fuelsystem_2bbl',
#  186: 'fuelsystem_4bbl',
#  187: 'fuelsystem_idi',
#  188: 'fuelsystem_mfi',
#  189: 'fuelsystem_mpfi',
#  190: 'fuelsystem_spdi',
#  191: 'fuelsystem_spfi'}

# %%
## we normalize data because data has big vlaues in decimal and it will worsen performance of our model, may overfit 
## or  we may face hardware resource high usage
# we will apply the formula normalized_train_data = (train_data - mean)/ stadrad_deviation
## firt take mean of training, then subtract mean from each value of the array slice train_data.iloc[:,0:13]
mean = train_data.iloc[:,0:13].mean(axis=0) # taking the mean of 
train_data.iloc[:,0:13] -= mean
std = train_data.iloc[:,0:13].std(axis=0)
train_data.iloc[:,0:13] /= std
test_data.iloc[:,0:13] -= mean
test_data.iloc[:,0:13] /= std

# %%
mean
# Out:
# wheelbase             98.692199
# carlength            173.658156
# carwidth              65.875887
# carheight             53.648227
# curbweight          2546.787234
# enginesize           125.666667
# boreratio              3.324184
# stroke                 3.256809
# compressionratio      10.070355
# horsepower           103.702128
# peakrpm             5143.971631
# citympg               25.113475
# highwaympg            30.581560
# dtype: float64

# %%
std
# Out:
# wheelbase             6.005665
# carlength            12.320089
# carwidth              2.188604
# carheight             2.508204
# curbweight          529.769152
# enginesize           41.733451
# boreratio             0.266123
# stroke                0.296387
# compressionratio      3.868579
# horsepower           38.424275
# peakrpm             474.472458
# citympg               6.509435
# highwaympg            6.734937
# dtype: float64

# %%
mean_label = train_label.mean()
train_label -= mean_label
std_label = train_label.std()
train_label /= std_label
test_label -= mean_label
test_label /= std_label

# %%
mean_label
# Out:
# 13379.132390070921

# %%
std_label
# Out:
# 8189.4945680106175

# %%
print(mean_label)
# Out:
# 13379.132390070921

# %%
test_label
# Out:
# 0      0.014148
# 10     0.372534
# 14     1.365880
# 15     2.122337
# 18    -1.004718
#          ...
# 192    0.056886
# 193   -0.132991
# 194   -0.053621
# 196    0.318196
# 198    0.615529
# Name: price, Length: 64, dtype: float64

# %%
train_data.shape
# Out:
# (141, 192)

# %%
#store in numpy array

# %%
test = np.array(test_data.iloc[:]).astype('float32')

# %%
train = np.array(train_data.iloc[:]).astype('float32')

# %%
test_l= np.array(test_label.astype('float32'))

# %%
train_l= np.array(train_label.astype('float32'))

# %%
train.shape[1]
# Out:
# 192

# %%
(141,192)[1]
# Out:
# 192

# %%
train.dtype
# Out:
# dtype('float32')

# %% [markdown]
# # Models section
# ```
# #WE will configure different models here according to relu, tanh , regularization, dropout etc..
# ```

# %%
# we are passing activation function as a parameter here so that we can call this function with tanh or relu while
# fitting and training the model
from keras import models
from keras import layers
def build_model(act):
  model = models.Sequential()
  model.add(layers.Dense(128, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dense(64, activation= act))
  model.add(layers.Dense(32, activation= act))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model('relu').summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               24704
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
build_model('tanh').summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Regularized model
from keras import regularizers
def build_model_regular(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001),input_shape=(train.shape[1],)))
  model.add(layers.Dense(8, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(6, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_regular('tanh').summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 10)                1930
# _________________________________________________________________
# dense_9 (Dense)              (None, 8)                 88
# _________________________________________________________________
# dense_10 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %%
# dropout model
from keras import regularizers
def build_model_drop(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(8, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(6, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_drop('relu').summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 10)                1930
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_14 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # K Fold validation section
# ## here we will use len(train)//k to make 141//4 = 36 rows for validation in each validation test and collect the validation scores for relu , tanh , regularization , and dropout

# %%
#k fold validation with relu
# 141/4
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_relu = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_relu.append(val_mae)
# Out:
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3

# %%
# 141/4
#k fold validation with tanh
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_tanh = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('tanh')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_tanh.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x7f475fb51d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f47660c4170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f47615a7d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f476394a170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with regularization
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_regular = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_regular('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_regular.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f475f212cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f47630017a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f475d727c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f475c4c9830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with dropout
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_drop = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_drop('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=1)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=1)
  all_scores_drop.append(val_mae)
# Out:
# processing fold # 0
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.7815 - mae: 0.6748
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5918 - mae: 0.5482
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3538 - mae: 0.4541
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4394 - mae: 0.4991
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2306 - mae: 0.3341
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4223 - mae: 0.4402
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4418 - mae: 0.4167
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8029 - mae: 0.5556
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3992 - mae: 0.3973
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4398 - mae: 0.4366
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4678 - mae: 0.4269
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4821 - mae: 0.4391
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2914 - mae: 0.3738
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2302 - mae: 0.3446
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3245 - mae: 0.3416
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4452 - mae: 0.3902
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2161 - mae: 0.3470
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2802 - mae: 0.3652
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7121 - mae: 0.4967
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2356 - mae: 0.2960
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2757 - mae: 0.3770
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2989 - mae: 0.3283
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4004 - mae: 0.3543
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2781 - mae: 0.3284
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2636 - mae: 0.3676
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2963 - mae: 0.2870
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1180 - mae: 0.2376
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4304 - mae: 0.3665
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4192 - mae: 0.3792
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2101 - mae: 0.3066
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2773 - mae: 0.3483
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1772 - mae: 0.2643
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4661 - mae: 0.3817
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1988 - mae: 0.2601
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1897 - mae: 0.3087
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4981 - mae: 0.4279
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2149 - mae: 0.2924
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1759 - mae: 0.2666
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2325 - mae: 0.3210
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8687 - mae: 0.4623
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2447 - mae: 0.2857
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1245 - mae: 0.2742
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3305 - mae: 0.3717
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1089 - mae: 0.2319
# Epoch 45/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4463 - mae: 0.3812
# Epoch 46/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2731 - mae: 0.3345
# Epoch 47/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2173 - mae: 0.3007
# Epoch 48/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2318 - mae: 0.3243
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1496 - mae: 0.2591
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3894 - mae: 0.3399
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4157 - mae: 0.3546
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1668 - mae: 0.2475
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2670 - mae: 0.3178
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1251 - mae: 0.2488
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4830 - mae: 0.3713
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2841 - mae: 0.3182
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1299 - mae: 0.2402
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2520 - mae: 0.3359
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4010 - mae: 0.3568
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2427 - mae: 0.3069
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4257 - mae: 0.3315
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2983 - mae: 0.3425
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1584 - mae: 0.2630
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1844 - mae: 0.2364
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1318 - mae: 0.2254
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3981 - mae: 0.2966
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2646 - mae: 0.3021
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2664 - mae: 0.3126
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1918 - mae: 0.2500
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2625 - mae: 0.3074
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1226 - mae: 0.2405
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3043 - mae: 0.3108
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2477 - mae: 0.2852
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2211 - mae: 0.2951
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3154 - mae: 0.3265
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2886 - mae: 0.3368
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1802 - mae: 0.2571
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1049 - mae: 0.2195
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2283 - mae: 0.2540
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2450 - mae: 0.2861
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1684 - mae: 0.2853
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2667 - mae: 0.2871
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2070 - mae: 0.2740
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3332 - mae: 0.3242
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3882 - mae: 0.3138
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1813 - mae: 0.2499
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1660 - mae: 0.2394
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2782 - mae: 0.2697
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1243 - mae: 0.2396
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1610 - mae: 0.2518
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1761 - mae: 0.2917
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3258 - mae: 0.3393
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2158 - mae: 0.3063
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2913 - mae: 0.2935
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1248 - mae: 0.2410
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2484 - mae: 0.3116
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2374 - mae: 0.3011
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1458 - mae: 0.2581
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2324 - mae: 0.2969
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2932 - mae: 0.3026
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f475d716b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3592 - mae: 0.3941
# processing fold # 1
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.5877 - mae: 0.6367
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6384 - mae: 0.5799
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7256 - mae: 0.5390
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5535 - mae: 0.5006
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4314 - mae: 0.4977
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3952 - mae: 0.4200
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2868 - mae: 0.3621
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3632 - mae: 0.4469
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3529 - mae: 0.3953
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3478 - mae: 0.4089
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2842 - mae: 0.3801
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1613 - mae: 0.3128
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2156 - mae: 0.3184
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2084 - mae: 0.3245
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2583 - mae: 0.3822
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4414 - mae: 0.4278
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2953 - mae: 0.3477
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1456 - mae: 0.2789
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6526 - mae: 0.4942
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2830 - mae: 0.3240
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2835 - mae: 0.3415
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1874 - mae: 0.3019
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3602 - mae: 0.3814
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2324 - mae: 0.3233
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4416 - mae: 0.3742
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1637 - mae: 0.2832
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1596 - mae: 0.2747
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1450 - mae: 0.2521
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1942 - mae: 0.2872
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1755 - mae: 0.2577
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2099 - mae: 0.2674
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1309 - mae: 0.2694
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4213 - mae: 0.3774
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1365 - mae: 0.2476
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1010 - mae: 0.2236
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1245 - mae: 0.2818
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2415 - mae: 0.2780
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2175 - mae: 0.3038
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1349 - mae: 0.2424
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3940 - mae: 0.3845
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1393 - mae: 0.2580
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2208 - mae: 0.3100
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1681 - mae: 0.2830
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1870 - mae: 0.3024
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1302 - mae: 0.2583
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1912 - mae: 0.2843
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2450 - mae: 0.3082
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2156 - mae: 0.2804
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1984 - mae: 0.3107
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1350 - mae: 0.2586
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2424 - mae: 0.3152
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2618 - mae: 0.3278
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1504 - mae: 0.2272
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1084 - mae: 0.2460
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2059 - mae: 0.2758
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0938 - mae: 0.2236
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1332 - mae: 0.2378
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2347 - mae: 0.3110
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0971 - mae: 0.2460
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3405 - mae: 0.3002
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1126 - mae: 0.2347
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2352 - mae: 0.2841
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0893 - mae: 0.2208
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2199 - mae: 0.2722
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1467 - mae: 0.2624
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1681 - mae: 0.2700
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1073 - mae: 0.2276
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1111 - mae: 0.2306
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1423 - mae: 0.2580
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1888 - mae: 0.2468
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1497 - mae: 0.2714
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1955 - mae: 0.2906
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0885 - mae: 0.1763
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2001 - mae: 0.2809
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0990 - mae: 0.2281
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2299 - mae: 0.3051
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2229 - mae: 0.2948
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2049 - mae: 0.2880
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1147 - mae: 0.2212
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1404 - mae: 0.2478
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1414 - mae: 0.2425
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1510 - mae: 0.2317
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2024 - mae: 0.2808
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0951 - mae: 0.2302
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2009 - mae: 0.2494
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1255 - mae: 0.2266
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1134 - mae: 0.2185
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0726 - mae: 0.2082
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2584 - mae: 0.2794
# Epoch 90/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1430 - mae: 0.2258
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1388 - mae: 0.2427
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1749 - mae: 0.2458
# Epoch 93/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1485 - mae: 0.2537
# Epoch 94/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.0833 - mae: 0.1990
# Epoch 95/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1603 - mae: 0.2595
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0571 - mae: 0.1525
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2981 - mae: 0.3478
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1343 - mae: 0.2255
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1451 - mae: 0.2171
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1727 - mae: 0.2828
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f475f2124d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5116 - mae: 0.4059
# processing fold # 2
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 1.6721 - mae: 0.8196
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.0161 - mae: 0.6751
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.1671 - mae: 0.6803
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9316 - mae: 0.6450
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7407 - mae: 0.5210
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.4025 - mae: 0.7577
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6689 - mae: 0.5057
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8300 - mae: 0.5953
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5695 - mae: 0.5161
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3859 - mae: 0.4200
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7456 - mae: 0.5087
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7060 - mae: 0.5470
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4554 - mae: 0.4380
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4035 - mae: 0.4138
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3580 - mae: 0.4177
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5387 - mae: 0.4884
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4363 - mae: 0.3921
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5044 - mae: 0.4512
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3590 - mae: 0.4135
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3588 - mae: 0.3849
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4551 - mae: 0.4321
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4489 - mae: 0.4033
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3070 - mae: 0.3692
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4540 - mae: 0.4910
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.0186 - mae: 0.5810
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4114 - mae: 0.4141
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3062 - mae: 0.3903
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2640 - mae: 0.3188
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5418 - mae: 0.4253
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2070 - mae: 0.3151
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3092 - mae: 0.3441
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1367 - mae: 0.2466
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4486 - mae: 0.4294
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5904 - mae: 0.4011
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4817 - mae: 0.4124
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3549 - mae: 0.4517
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6057 - mae: 0.4160
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2502 - mae: 0.3458
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2965 - mae: 0.3431
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5089 - mae: 0.4260
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4976 - mae: 0.3847
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5013 - mae: 0.4333
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2209 - mae: 0.3065
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3030 - mae: 0.3649
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2300 - mae: 0.3005
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1975 - mae: 0.2986
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3362 - mae: 0.3244
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4344 - mae: 0.4217
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4334 - mae: 0.4343
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1635 - mae: 0.2592
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2866 - mae: 0.3259
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5045 - mae: 0.4424
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1966 - mae: 0.2682
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3913 - mae: 0.4267
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3847 - mae: 0.3932
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1847 - mae: 0.2674
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6155 - mae: 0.4253
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2013 - mae: 0.2845
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4751 - mae: 0.4645
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3545 - mae: 0.3753
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4254 - mae: 0.3675
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6297 - mae: 0.4723
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2474 - mae: 0.2961
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2261 - mae: 0.3290
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4091 - mae: 0.4311
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1544 - mae: 0.2856
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2708 - mae: 0.3148
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2999 - mae: 0.3704
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2277 - mae: 0.3292
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2716 - mae: 0.3679
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4064 - mae: 0.3974
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2402 - mae: 0.3261
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2535 - mae: 0.3002
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3366 - mae: 0.3566
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2047 - mae: 0.3087
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1631 - mae: 0.3202
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3376 - mae: 0.3684
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1867 - mae: 0.2568
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2263 - mae: 0.3080
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1698 - mae: 0.3121
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4562 - mae: 0.4114
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1933 - mae: 0.3049
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2024 - mae: 0.3253
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3228 - mae: 0.3261
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1737 - mae: 0.2905
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3251 - mae: 0.2794
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1973 - mae: 0.2870
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1691 - mae: 0.2570
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3472 - mae: 0.3311
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1725 - mae: 0.2989
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5244 - mae: 0.4080
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4342 - mae: 0.3750
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2348 - mae: 0.3198
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4195 - mae: 0.3685
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2310 - mae: 0.3479
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2664 - mae: 0.3129
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2864 - mae: 0.3448
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1299 - mae: 0.2551
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4695 - mae: 0.3435
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2396 - mae: 0.3561
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4761e7e830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4237 - mae: 0.4809
# processing fold # 3
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 1.3220 - mae: 0.7918
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.4724 - mae: 0.7517
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8773 - mae: 0.6234
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.3114 - mae: 0.7227
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5112 - mae: 0.4942
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7757 - mae: 0.5773
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8950 - mae: 0.6363
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4902 - mae: 0.5095
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3881 - mae: 0.4862
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5698 - mae: 0.5549
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6127 - mae: 0.4775
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4752 - mae: 0.5043
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7678 - mae: 0.6114
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5009 - mae: 0.4574
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5397 - mae: 0.4457
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4292 - mae: 0.4540
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7092 - mae: 0.5251
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8323 - mae: 0.5611
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3059 - mae: 0.3745
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4771 - mae: 0.4923
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2763 - mae: 0.3575
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3079 - mae: 0.3865
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5231 - mae: 0.4670
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4488 - mae: 0.4263
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4058 - mae: 0.4085
# Epoch 26/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4529 - mae: 0.4646
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5075 - mae: 0.4800
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3788 - mae: 0.4025
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4005 - mae: 0.4524
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6072 - mae: 0.4523
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3422 - mae: 0.3970
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2771 - mae: 0.3736
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3389 - mae: 0.3546
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4299 - mae: 0.4550
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3210 - mae: 0.4143
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4146 - mae: 0.4017
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1409 - mae: 0.2749
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6126 - mae: 0.5154
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3108 - mae: 0.3660
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2876 - mae: 0.3976
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2166 - mae: 0.3013
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6339 - mae: 0.4920
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4320 - mae: 0.4161
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2308 - mae: 0.3596
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3960 - mae: 0.3818
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2096 - mae: 0.2996
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2951 - mae: 0.3602
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4006 - mae: 0.4313
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3714 - mae: 0.4088
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3231 - mae: 0.3598
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3240 - mae: 0.3533
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2748 - mae: 0.3477
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4783 - mae: 0.4159
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6642 - mae: 0.5408
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6960 - mae: 0.4938
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2059 - mae: 0.3518
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6518 - mae: 0.4749
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5280 - mae: 0.4447
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4203 - mae: 0.3865
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3148 - mae: 0.3070
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1865 - mae: 0.2853
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3823 - mae: 0.3780
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2496 - mae: 0.2968
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8916 - mae: 0.5928
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3837 - mae: 0.3984
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2828 - mae: 0.2990
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2213 - mae: 0.3220
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2664 - mae: 0.3483
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1431 - mae: 0.2172
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5033 - mae: 0.4470
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5741 - mae: 0.4492
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4360 - mae: 0.3805
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2630 - mae: 0.3301
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3782 - mae: 0.3804
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3980 - mae: 0.3974
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3014 - mae: 0.3202
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3932 - mae: 0.3905
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3999 - mae: 0.3923
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3341 - mae: 0.3486
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4437 - mae: 0.3958
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5193 - mae: 0.4448
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3592 - mae: 0.3938
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2959 - mae: 0.3503
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4640 - mae: 0.4292
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1417 - mae: 0.2629
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2619 - mae: 0.2976
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3840 - mae: 0.3711
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5023 - mae: 0.3607
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3040 - mae: 0.3293
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9291 - mae: 0.5254
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2796 - mae: 0.2972
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2051 - mae: 0.2746
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3186 - mae: 0.3334
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7148 - mae: 0.4500
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3701 - mae: 0.3734
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3255 - mae: 0.3286
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3823 - mae: 0.3388
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3273 - mae: 0.3253
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1581 - mae: 0.2317
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3385 - mae: 0.3434
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f47638ff440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2129 - mae: 0.3628

# %% [markdown]
# # Scores
# ## here we will see  MAE mean absolute Error scores of all model which we have saved in the list during each training in above section

# %%
all_scores_relu
# Out:
# [0.29680928587913513,
#  0.4188464879989624,
#  0.37897753715515137,
#  0.33279281854629517]

# %%
all_scores_tanh
# Out:
# [0.3297230303287506,
#  0.32994863390922546,
#  0.5369722843170166,
#  0.2756673991680145]

# %%
all_scores_regular
# Out:
# [0.42971593141555786,
#  0.2500198781490326,
#  0.31933778524398804,
#  0.3561462163925171]

# %%
all_scores_drop
# Out:
# [0.39410606026649475,
#  0.4058891534805298,
#  0.48092612624168396,
#  0.36280557513237]

# %% [markdown]
# # training on the training data
# ## here we will call each model separately from Models section and train on the training data and evaluate on the test data

# %%
model_tanh = build_model('tanh')
model_tanh.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_tanh.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4760cd77a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1066 - mae: 0.2487

# %%
model_relu = build_model('relu')
model_relu.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_relu.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4763085290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0684 - mae: 0.2062

# %%
model_regular = build_model_regular('relu')
model_regular.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_regular.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4762fad7a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1236 - mae: 0.2345

# %%
model_drop = build_model_drop('relu')
model_drop.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_drop.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4765810680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2480 - mae: 0.3853

# %% [markdown]
# # Prediction Section
# ## here we will predict our prices of our test dataset with each model which we have trained in training section
# ## Note that here we will use the reverse process of Normalization to retrieve our values of price in thousand of dollars i.e. x = (y - mean)/ std ==>> we will calculate( y = x * std + mean) and then we will compare it with our target values

# %%
test_l
# Out:
# array([ 0.01414832,  0.3725343 ,  1.3658801 ,  2.122337  , -1.004718  ,
#        -0.7045773 , -0.5886972 , -0.97443527, -0.763189  , -0.52312535,
#        -0.05301089, -0.3704908 , -0.5449216 , -0.80397296, -0.5536523 ,
#        -0.26059392,  0.6062484 ,  1.4864004 ,  2.5404336 ,  3.367835  ,
#        -0.8779702 , -0.09159691,  0.18192424, -0.7802841 , -0.50065756,
#        -0.9622245 , -0.6813769 , -0.5409531 ,  0.01463675,  0.12453365,
#         0.46643507, -0.1806134 ,  0.2687428 ,  0.4299249 ,  0.45129374,
#        -0.07511237,  2.3382235 ,  2.200547  , -0.49870384,  0.20280465,
#         0.26019526, -0.68430746, -0.7224051 , -0.65524584, -0.98066276,
#        -0.7889537 , -0.7547636 , -0.6888255 , -0.6277716 , -0.4983375 ,
#        -0.6020069 , -0.4139611 , -0.22347318, -0.54107517,  0.28217462,
#        -0.68430746, -0.6574438 , -0.59638995, -0.01027321,  0.056886  ,
#        -0.1329914 , -0.05362143,  0.3181964 ,  0.6155285 ], dtype=float32)

# %%
def predict(model, m):
  print(f" the Actual value Price was : {test_l[m]* std_label + mean_label} " )
  return(f" the predicted Price was : {(model.predict(test[m:m+1].reshape(1,test.shape[1]))) * std_label + mean_label} ")

# %%
x_tanh = predict(model_tanh,2)
x_tanh
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[23148.992]] '

# %%
x_relu = predict(model_relu,2)
x_relu
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[22068.068]] '

# %%
x_regular = predict(model_regular,2)
x_regular
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[20649.904]] '

# %%
x_drop = predict(model_drop,2)
x_drop
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[20386.508]] '

# %%
def plot_fn(mod):
  y_true = test_l* std_label + mean_label
  y_pred = mod.predict(test) * std_label + mean_label
  return y_true , y_pred.flatten()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
def plotting(mod, label):
  y_true, y_pred = plot_fn(mod)
  coef = np.polyfit(y_true,y_pred,1)
  poly1d_fn = np.poly1d(coef) 
  # poly1d_fn is now a function which takes in x and returns an estimate for y
  plt.figure()
  plt.plot(y_true,y_pred, 'yo', y_true, poly1d_fn(y_true), '--k')
  plt.title(label)
  plt.xlabel('Thousand Dollar True' )
  plt.ylabel('Thousand Dollar Predictions' )
  plt.xlim(0, 50000)
  plt.ylim(0, 50000)

# %%
plot_list = []
for i,j in enumerate([model_relu, model_tanh, model_regular, model_drop]):
  list_name = ['model_relu', 'model_tanh', 'model_regular', 'model_drop']
  plot_list.append(plotting(j,list_name[i]))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f475df9a710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f476610ff80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f475f212290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f475f2187a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
